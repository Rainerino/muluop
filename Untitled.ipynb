# %%
# !which python
# Out:
# /usr/bin/python

# %%
import torch
import mujoco
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 import mujoco
#
# ModuleNotFoundError: No module named 'torch'
